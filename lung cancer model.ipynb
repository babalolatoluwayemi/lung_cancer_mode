# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import pickle

# %%
#importing the dataset
path = "C:/Users/USER/Documents/PROJECT/survey lung cancer.csv"
df = pd.read_csv(path)
df
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# 1                  2         2         2         1                  1
# 2                  1         2         1         2                  1
# 3                  1         1         1         1                  2
# 4                  1         1         1         2                  1
# ..               ...       ...       ...       ...                ...
# 304                2         2         1         1                  2
# 305                1         2         2         2                  2
# 306                1         1         2         2                  2
# 307                1         2         2         1                  2
# 308                1         2         2         2                  2
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 0           2                    2                      2           2
# 1           1                    2                      2           2
# 2           2                    2                      1           2
# 3           1                    1                      2           2
# 4           2                    2                      1           1
# ..        ...                  ...                    ...         ...
# 304         2                    2                      2           1
# 305         2                    2                      1           2
# 306         2                    1                      1           2
# 307         2                    2                      1           2
# 308         1                    1                      2           1
#
#     LUNG_CANCER
# 0           YES
# 1           YES
# 2            NO
# 3            NO
# 4            NO
# ..          ...
# 304         YES
# 305         YES
# 306         YES
# 307         YES
# 308         YES
#
# [309 rows x 16 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# 1                  2         2         2         1                  1
# 2                  1         2         1         2                  1
# 3                  1         1         1         1                  2
# 4                  1         1         1         2                  1
# ..               ...       ...       ...       ...                ...
# 304                2         2         1         1                  2
# 305                1         2         2         2                  2
# 306                1         1         2         2                  2
# 307                1         2         2         1                  2
# 308                1         2         2         2                  2
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 0           2                    2                      2           2
# 1           1                    2                      2           2
# 2           2                    2                      1           2
# 3           1                    1                      2           2
# 4           2                    2                      1           1
# ..        ...                  ...                    ...         ...
# 304         2                    2                      2           1
# 305         2                    2                      1           2
# 306         2                    1                      1           2
# 307         2                    2                      1           2
# 308         1                    1                      2           1
#
#     LUNG_CANCER
# 0           YES
# 1           YES
# 2            NO
# 3            NO
# 4            NO
# ..          ...
# 304         YES
# 305         YES
# 306         YES
# 307         YES
# 308         YES
#
# [309 rows x 16 columns]>

# %%
#df.isna()
df.isna().head(1)
# Out:
#    GENDER    AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0   False  False    False           False    False          False
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0            False     False     False     False              False     False
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  LUNG_CANCER
# 0                False                  False       False        False

# %%
df.isna().sum().to_frame().T.style.set_properties(**{"background-color": "white","color":"blue","border": "0.5px  solid black"})
# Out:
# <style type="text/css">
# #T_f0dbd_row0_col0, #T_f0dbd_row0_col1, #T_f0dbd_row0_col2, #T_f0dbd_row0_col3, #T_f0dbd_row0_col4, #T_f0dbd_row0_col5, #T_f0dbd_row0_col6, #T_f0dbd_row0_col7, #T_f0dbd_row0_col8, #T_f0dbd_row0_col9, #T_f0dbd_row0_col10, #T_f0dbd_row0_col11, #T_f0dbd_row0_col12, #T_f0dbd_row0_col13, #T_f0dbd_row0_col14, #T_f0dbd_row0_col15 {
#   background-color: white;
#   color: blue;
#   border: 0.5px  solid black;
# }
# </style>
# <table id="T_f0dbd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >GENDER</th>
#       <th class="col_heading level0 col1" >AGE</th>
#       <th class="col_heading level0 col2" >SMOKING</th>
#       <th class="col_heading level0 col3" >YELLOW_FINGERS</th>
#       <th class="col_heading level0 col4" >ANXIETY</th>
#       <th class="col_heading level0 col5" >PEER_PRESSURE</th>
#       <th class="col_heading level0 col6" >CHRONIC DISEASE</th>
#       <th class="col_heading level0 col7" >FATIGUE </th>
#       <th class="col_heading level0 col8" >ALLERGY </th>
#       <th class="col_heading level0 col9" >WHEEZING</th>
#       <th class="col_heading level0 col10" >ALCOHOL CONSUMING</th>
#       <th class="col_heading level0 col11" >COUGHING</th>
#       <th class="col_heading level0 col12" >SHORTNESS OF BREATH</th>
#       <th class="col_heading level0 col13" >SWALLOWING DIFFICULTY</th>
#       <th class="col_heading level0 col14" >CHEST PAIN</th>
#       <th class="col_heading level0 col15" >LUNG_CANCER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0dbd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f0dbd_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_f0dbd_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_f0dbd_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_f0dbd_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f0dbd_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f0dbd_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_f0dbd_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_f0dbd_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_f0dbd_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_f0dbd_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_f0dbd_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_f0dbd_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_f0dbd_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_f0dbd_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_f0dbd_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_f0dbd_row0_col15" class="data row0 col15" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.describe()
# Out:
#               AGE     SMOKING  YELLOW_FINGERS     ANXIETY  PEER_PRESSURE  \
# count  309.000000  309.000000      309.000000  309.000000     309.000000
# mean    62.673139    1.563107        1.569579    1.498382       1.501618
# std      8.210301    0.496806        0.495938    0.500808       0.500808
# min     21.000000    1.000000        1.000000    1.000000       1.000000
# 25%     57.000000    1.000000        1.000000    1.000000       1.000000
# 50%     62.000000    2.000000        2.000000    1.000000       2.000000
# 75%     69.000000    2.000000        2.000000    2.000000       2.000000
# max     87.000000    2.000000        2.000000    2.000000       2.000000
#
#        CHRONIC DISEASE    FATIGUE     ALLERGY     WHEEZING  ALCOHOL CONSUMING  \
# count       309.000000  309.000000  309.000000  309.000000         309.000000
# mean          1.504854    1.673139    1.556634    1.556634           1.556634
# std           0.500787    0.469827    0.497588    0.497588           0.497588
# min           1.000000    1.000000    1.000000    1.000000           1.000000
# 25%           1.000000    1.000000    1.000000    1.000000           1.000000
# 50%           2.000000    2.000000    2.000000    2.000000           2.000000
# 75%           2.000000    2.000000    2.000000    2.000000           2.000000
# max           2.000000    2.000000    2.000000    2.000000           2.000000
#
#          COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN
# count  309.000000           309.000000             309.000000  309.000000
# mean     1.579288             1.640777               1.469256    1.556634
# std      0.494474             0.480551               0.499863    0.497588
# min      1.000000             1.000000               1.000000    1.000000
# 25%      1.000000             1.000000               1.000000    1.000000
# 50%      2.000000             2.000000               1.000000    2.000000
# 75%      2.000000             2.000000               2.000000    2.000000
# max      2.000000             2.000000               2.000000    2.000000

# %%
df.describe(include=object).T.style.set_properties(**{"background-color": "white","color":"blue","border": "1.5px  black"})
# Out:
# <style type="text/css">
# #T_17f4b_row0_col0, #T_17f4b_row0_col1, #T_17f4b_row0_col2, #T_17f4b_row0_col3, #T_17f4b_row1_col0, #T_17f4b_row1_col1, #T_17f4b_row1_col2, #T_17f4b_row1_col3 {
#   background-color: white;
#   color: blue;
#   border: 1.5px  black;
# }
# </style>
# <table id="T_17f4b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >unique</th>
#       <th class="col_heading level0 col2" >top</th>
#       <th class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17f4b_level0_row0" class="row_heading level0 row0" >GENDER</th>
#       <td id="T_17f4b_row0_col0" class="data row0 col0" >309</td>
#       <td id="T_17f4b_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_17f4b_row0_col2" class="data row0 col2" >M</td>
#       <td id="T_17f4b_row0_col3" class="data row0 col3" >162</td>
#     </tr>
#     <tr>
#       <th id="T_17f4b_level0_row1" class="row_heading level0 row1" >LUNG_CANCER</th>
#       <td id="T_17f4b_row1_col0" class="data row1 col0" >309</td>
#       <td id="T_17f4b_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_17f4b_row1_col2" class="data row1 col2" >YES</td>
#       <td id="T_17f4b_row1_col3" class="data row1 col3" >270</td>
#     </tr>
#   </tbody>
# </table>

# %%
#The corr() function displays the correlation between different variables in our dataset
df.corr()
# Out:
#                             AGE   SMOKING  YELLOW_FINGERS   ANXIETY  \
# AGE                    1.000000 -0.084475        0.005205  0.053170
# SMOKING               -0.084475  1.000000       -0.014585  0.160267
# YELLOW_FINGERS         0.005205 -0.014585        1.000000  0.565829
# ANXIETY                0.053170  0.160267        0.565829  1.000000
# PEER_PRESSURE          0.018685 -0.042822        0.323083  0.216841
# CHRONIC DISEASE       -0.012642 -0.141522        0.041122 -0.009678
# FATIGUE                0.012614 -0.029575       -0.118058 -0.188538
# ALLERGY                0.027990  0.001913       -0.144300 -0.165750
# WHEEZING               0.055011 -0.129426       -0.078515 -0.191807
# ALCOHOL CONSUMING      0.058985 -0.050623       -0.289025 -0.165750
# COUGHING               0.169950 -0.129471       -0.012640 -0.225644
# SHORTNESS OF BREATH   -0.017513  0.061264       -0.105944 -0.144077
# SWALLOWING DIFFICULTY -0.001270  0.030718        0.345904  0.489403
# CHEST PAIN            -0.018104  0.120117       -0.104829 -0.113634
#
#                        PEER_PRESSURE  CHRONIC DISEASE  FATIGUE
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# 1                  2         2         2         1                  1
# 2                  1         2         1         2                  1
# 3                  1         1         1         1                  2
# 4                  1         1         1         2                  1
# ..               ...       ...       ...       ...                ...
# 279                1         1         2         2                  1
# 280                2         2         2         1                  1
# 281                1         2         2         1                  1
# 282                1         1         1         1                  1
# 283                1         2         1         2                  2
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 0           2                    2                      2           2
# 1           1                    2                      2           2
# 2           2                    2                      1           2
# 3           1                    1                      2           2
# 4           2                    2                      1           1
# ..        ...                  ...                    ...         ...
# 279         2                    1                      2           1
# 280         1                    2                      1           1
# 281         1                    2                      1           2
# 282         1                    1                      2           2
# 283         2                    2                      2           2
#
#     LUNG_CANCER
# 0           YES
# 1           YES
# 2            NO
# 3            NO
# 4            NO
# ..          ...
# 279         YES
# 280          NO
# 281          NO
# 282          NO
# 283         YES
#
# [276 rows x 16 columns]

# %%
duplicate = df[df1.duplicated()].shape[0]
print(f"There are {duplicate} duplicate entries among {df1.shape[0]} entries in this dataset.")

df1.drop_duplicates(keep='first',inplace=True)
print(f"\nAfter removing duplicate entries there are {df1.shape[0]} entries in this dataset.")
# Out:
# There are 33 duplicate entries among 309 entries in this dataset.
#
# After removing duplicate entries there are 276 entries in this dataset.

# %%
#data_temp = data.copy()
df2["GENDER"] = df2["GENDER"].replace({"M" : "Male" , "F" : "Female"})

for column in df2:
    df2[column] = df2[column].replace({2: "Yes" , 1 : "No"})
for column in df2:
   df2[column] = df2[column].replace({"Yes" : 1, "No": 0})
df2.head().style.set_properties(**{"background-color": "white","color":"black","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_0d27b_row0_col0, #T_0d27b_row0_col1, #T_0d27b_row0_col2, #T_0d27b_row0_col3, #T_0d27b_row0_col4, #T_0d27b_row0_col5, #T_0d27b_row0_col6, #T_0d27b_row0_col7, #T_0d27b_row0_col8, #T_0d27b_row0_col9, #T_0d27b_row0_col10, #T_0d27b_row0_col11, #T_0d27b_row0_col12, #T_0d27b_row0_col13, #T_0d27b_row0_col14, #T_0d27b_row0_col15, #T_0d27b_row1_col0, #T_0d27b_row1_col1, #T_0d27b_row1_col2, #T_0d27b_row1_col3, #T_0d27b_row1_col4, #T_0d27b_row1_col5, #T_0d27b_row1_col6, #T_0d27b_row1_col7, #T_0d27b_row1_col8, #T_0d27b_row1_col9, #T_0d27b_row1_col10, #T_0d27b_row1_col11, #T_0d27b_row1_col12, #T_0d27b_row1_col13, #T_0d27b_row1_col14, #T_0d27b_row1_col15, #T_0d27b_row2_col0, #T_0d27b_row2_col1, #T_0d27b_row2_col2, #T_0d27b_row2_col3, #T_0d27b_row2_col4, #T_0d27b_row2_col5, #T_0d27b_row2_col6, #T_0d27b_row2_col7, #T_0d27b_row2_col8, #T_0d27b_row2_col9, #T_0d27b_row2_col10, #T_0d27b_row2_col11, #T_0d27b_row2_col12, #T_0d27b_row2_col13, #T_0d27b_row2_col14, #T_0d27b_row2_col15, #T_0d27b_row3_col0, #T_0d27b_row3_col1, #T_0d27b_row3_col2, #T_0d27b_row3_col3, #T_0d27b_row3_col4, #T_0d27b_row3_col5, #T_0d27b_row3_col6, #T_0d27b_row3_col7, #T_0d27b_row3_col8, #T_0d27b_row3_col9, #T_0d27b_row3_col10, #T_0d27b_row3_col11, #T_0d27b_row3_col12, #T_0d27b_row3_col13, #T_0d27b_row3_col14, #T_0d27b_row3_col15, #T_0d27b_row4_col0, #T_0d27b_row4_col1, #T_0d27b_row4_col2, #T_0d27b_row4_col3, #T_0d27b_row4_col4, #T_0d27b_row4_col5, #T_0d27b_row4_col6, #T_0d27b_row4_col7, #T_0d27b_row4_col8, #T_0d27b_row4_col9, #T_0d27b_row4_col10, #T_0d27b_row4_col11, #T_0d27b_row4_col12, #T_0d27b_row4_col13, #T_0d27b_row4_col14, #T_0d27b_row4_col15 {
#   background-color: white;
#   color: black;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 278         0                    1                      1           0
# 279         1                    0                      1           0
# 280         0                    1                      0           0
# 281         0                    1                      0           1
# 282         0                    0                      1           1
# 283         1                    1                      1           1
#
#     Biomarker LUNG_CANCER
# 278      bTMB         YES
# 279       ALK         YES
# 280       Nil          NO
# 281       Nil          NO
# 282       Nil          NO
# 283       ESO         YES

# %%
#data visualization
sns.set_style('whitegrid') # plot stlye
#pair plot method
sns.pairplot(df3[['ALCOHOL CONSUMING','COUGHING','CHEST PAIN','Biomarker', 'SHORTNESS OF BREATH','SMOKING', 'GENDER']],
            hue = 'Biomarker',
             height = 5,)

# %%
sns.heatmap(df3.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
plt.subplots(figsize=(12, 12))

labels = 'bTMB', 'EGFR', 'ALK', 'cfDNA' , 'ESO', 'Nil'
size = 0.5
#Biomarker= ['bTMB', 'EGFR', 'ALK', 'cfDNA' , 'ESO']


wedges, texts, autotexts = plt.pie([len(df3[df3["Biomarker"]=="bTMB"]["Biomarker"]),
                                    len(df3[df3["Biomarker"]=="EGFR"]["Biomarker"]),
                                    len(df3[df3["Biomarker"]=="ALK"]["Biomarker"]),
                                    len(df3[df3["Biomarker"]=="cfDNA"]["Biomarker"]),
                                    len(df3[df3["Biomarker"]=="ESO"]["Biomarker"]),
                                    len(df3[df3["Biomarker"]=="Nil"]["Biomarker"])],
                                    explode = (0,0,0,0,0,0),
                                    textprops=dict(size= 25, color= "white"),
                                    autopct="%.2f%%", 
                                    pctdistance = 0.7,
                                    radius=.9, 
                                    colors = ["yellow","violet", "blue", "pink", "green","red"], 
                                    shadow = True,
                                    wedgeprops=dict(width = size, edgecolor = "white", 
                                    linewidth = 6),
                                    startangle = 0)

plt.legend(wedges, labels, title="Category",loc="center left",bbox_to_anchor=(1, 0, 0.8, 1))
plt.title("\nPositive Cases' Biomarker Distribution",fontsize=20)
plt.show()

# %%
plt.subplots(figsize=(12, 12))

labels = "NO","YES"
size = 0.5

wedges, texts, autotexts = plt.pie([len(df3[df3["LUNG_CANCER"]=="NO"]["LUNG_CANCER"]),
                                    len(df3[df3["LUNG_CANCER"]=="YES"]["LUNG_CANCER"])],
                                    explode = (0,0),
                                    textprops=dict(size= 25, color= "black"),
                                    autopct="%.2f%%", 
                                    pctdistance = 0.7,
                                    radius=.9, 
                                    colors = ["blue","yellow"], 
                                    shadow = True,
                                    wedgeprops=dict(width = size, edgecolor = "white", 
                                    linewidth = 5),
                                    startangle = 0)

plt.legend(wedges, labels, title="Category",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))
plt.title("\nPositive Cases' LUNG_CANCER Distribution",fontsize=20)
plt.show()

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
X= df3.iloc[:,1:15]   #all features
Y= df3.iloc[:,-1]   #target output (Biomarkers)
best_features= SelectKBest(score_func=chi2, k=3)
fit= best_features.fit(X,Y)
df_scores= pd.DataFrame(fit.scores_)
df_columns= pd.DataFrame(X.columns)

# %%
# for traing and testing of the model
x_train, x_test, y_train, y_test =train_test_split(X,Y, test_size=0.3, random_state =40)
#for validation of the model
x_val, x_v_test, y_val, y_v_test =train_test_split(x_test,y_test, test_size=0.5, random_state =42)

# %%
X.shape
# Out:
# (276, 14)

# %%
Y.shape
# Out:
# (276,)

# %%
x_test
# Out:
#      AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC DISEASE  \
# 65    71        1               1        1              1                1
# 18    68        1               1        1              1                1
# 102   64        1               0        0              0                0
# 157   57        1               1        0              1                0
# 179   72        1               1        1              1                0
# ..   ...      ...             ...      ...            ...              ...
# 246   71        1               1        1              0                1
# 135   69        0               0        1              0                0
# 90    62        0               0        0              1                0
# 241   59        1               0        0              0                0
# 193   64        0               0        0              1                1
#
#      FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 65          1         0         1                  0         1
# 18          1         0         0                  0         1
# 102         1         1         1                  1         1
# 157         0         0         0                  0         0
# 179         1         0         1                  0         1
# ..        ...       ...       ...                ...       ...
# 246         0         0         1                  1         0
# 135         1         0         1                  1         1
# 90          0         0         1                  1         0
# 241         1         1         1                  1         1
# 193         0         0         0                  0         0
#
#      SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN
# 65                     0                      1           1
# 18                     1                      0           0
# 102                    1                      0           1
# 157                    0                      0           1
# 179                    1                      1           0
# ..                   ...                    ...         ...
# 246                    1                      1           1
# 135                    1                      1           0
# 90                     0                      1           1
# 241                    1                      0           1
# 193                    0                      0           0
#
# [83 rows x 14 columns]

# %%
x_test.shape
# Out:
# (83, 14)

# %%
y_test.shape
# Out:
# (83,)

# %%
y_train
# Out:
# 191    YES
# 114    YES
# 28     YES
# 81     YES
# 248    YES
#       ...
# 276    YES
# 196    YES
# 168    YES
# 7      YES
# 225    YES
# Name: LUNG_CANCER, Length: 193, dtype: object

# %%
x_train.shape
# Out:
# (193, 14)

# %%
y_train.shape
# Out:
# (193,)

# %%
logreg= LogisticRegression()
logreg.fit(x_train,y_train)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=logreg.predict(x_test)
print (x_test) #test dataset
print (y_pred) #predicted values
# Out:
#      AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC DISEASE  \
# 65    71        1               1        1              1                1
# 18    68        1               1        1              1                1
# 102   64        1               0        0              0                0
# 157   57        1               1        0              1                0
# 179   72        1               1        1              1                0
# ..   ...      ...             ...      ...            ...              ...
# 246   71        1               1        1              0                1
# 135   69        0               0        1              0                0
# 90    62        0               0        0              1                0
# 241   59        1               0        0              0                0
# 193   64        0               0        0              1                1
#
#      FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 65          1         0         1                  0         1
# 18          1         0         0                  0         1
# 102         1         1         1                  1         1
# 157         0         0         0                  0         0
# 179         1         0         1                  0         1
# ..        ...       ...       ...                ...       ...
# 246         0         0         1                  1         0
# 135         1         0         1                  1         1
# 90          0         0         1                  1         0
# 241         1         1         1                  1         1
# 193         0         0         0                  0         0
#
#      SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN
# 65                     0                      1           1
# 18                     1                      0           0
# 102                    1                      0           1
# 157                    0                      0           1
# 179                    1                      1           0
# ..                   ...                    ...         ...
# 246                    1                      1           1
# 135                    1                      1           0
# 90                     0                      1           1
# 241                    1                      0           1
# 193                    0                      0           0
#
# [83 rows x 14 columns]
# ['YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'NO'
#  'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'NO']

# %%
# freature scaling
from sklearn.preprocessing import StandardScaler
x_train = StandardScaler().fit_transform(x_train)
x_test = StandardScaler().fit_transform(x_test)

# %%
def models(x_train, y_train):
    #Logistic regression
    from sklearn.linear_model import LogisticRegression
    log = LogisticRegression(random_state = 0)
    log.fit(x_train,y_train)
    
    #creating a decision tree
    from sklearn.tree import DecisionTreeClassifier
    tree= DecisionTreeClassifier(random_state = 0, criterion = "entropy")
    tree.fit(x_train,y_train)
    
    #creating a ramdom forest
    from sklearn.ensemble import RandomForestClassifier
    forest = RandomForestClassifier(random_state = 0, criterion = "entropy", n_estimators = 10)
    forest.fit(x_train,y_train)
    
    #for accuracy
    print('[0]logistic regression accuracy: ', log.score(x_train,y_train))
    print('[1]Decision Tree accuracy: ', tree.score(x_train,y_train))
    print('[2]Random Forest accuracy: ', forest.score(x_train,y_train))
    
    
    return log, tree, forest

# %%
model = models(x_train,y_train)
# Out:
# [0]logistic regression accuracy:  0.9378238341968912
# [1]Decision Tree accuracy:  1.0
# [2]Random Forest accuracy:  0.9896373056994818

# %%
#testing the model and result and validation
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

for i in range(len(model)):
    print("model", i)
    print(classification_report(y_test, model[i].predict(x_test)))
    print("Accuracy : ", accuracy_score(y_test, model[i].predict(x_test)))
# Out:
# model 0
#               precision    recall  f1-score   support
#
#           NO       0.78      0.58      0.67        12
#          YES       0.93      0.97      0.95        71
#
#     accuracy                           0.92        83
#    macro avg       0.86      0.78      0.81        83
# weighted avg       0.91      0.92      0.91        83
#
# Accuracy :  0.9156626506024096
# model 1
#               precision    recall  f1-score   support
#
#           NO       0.42      0.67      0.52        12
#          YES       0.94      0.85      0.89        71
#
#     accuracy                           0.82        83
#    macro avg       0.68      0.76      0.70        83
# weighted avg       0.86      0.82      0.83        83
#
# Accuracy :  0.8192771084337349
# model 2
#               precision    recall  f1-score   support
#
#           NO       0.70      0.58      0.64        12
#          YES       0.93      0.96      0.94        71
#
#     accuracy                           0.90        83
#    macro avg       0.82      0.77      0.79        83
# weighted avg       0.90      0.90      0.90        83
#
# Accuracy :  0.9036144578313253

# %%
#predicting the random forest

pred= model[2].predict(x_test)
print("the predicted value: ")
print(pred)
print('the actual value')
print(y_test)
# Out:
# the predicted value:
# ['YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'NO' 'YES' 'YES' 'NO'
#  'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'NO' 'YES'
#  'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'NO']
# the actual value
# 65     YES
# 18     YES
# 102    YES
# 157     NO
# 179    YES
#       ...
# 246    YES
# 135    YES
# 90     YES
# 241    YES
# 193    YES
# Name: LUNG_CANCER, Length: 83, dtype: object

# %%
plt.plot(x_test, pred, color='red', linewidth=0.1)
plt.xlabel('True value')
plt.ylabel('predicted value')
#plt.xticks(())
#plt.yticks(())
plt.show()

# %%
pre= model[1].predict(x_test)
print("the predicted value: ")
print(pre)
print('the actual value')
print(y_test)
# Out:
# the predicted value:
# ['YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES'
#  'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'NO' 'YES' 'NO' 'YES' 'YES' 'YES' 'NO' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'YES' 'NO' 'YES' 'YES' 'NO' 'YES' 'YES' 'NO' 'YES' 'NO' 'NO' 'YES'
#  'YES' 'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES'
#  'NO' 'YES' 'NO' 'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'NO']
# the actual value
# 65     YES
# 18     YES
# 102    YES
# 157     NO
# 179    YES
#       ...
# 246    YES
# 135    YES
# 90     YES
# 241    YES
# 193    YES
# Name: LUNG_CANCER, Length: 83, dtype: object

# %%
x_test.shape
# Out:
# (83, 14)

# %%
y_test.shape
# Out:
# (83,)

# %%
# to save the model
filename = "cancer model"
pickle.dump(model,open(filename, "wb"))
print("model successsfully save")

#to load the model
load_model = pickle.load(open(filename, "rb"))
load_model
# Out:
# model successsfully save
# (LogisticRegression(random_state=0),
#  DecisionTreeClassifier(criterion='entropy', random_state=0),
#  RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0))

# %%
import joblib
joblib.dump(model, "cancer.joblib")
print("model save")

load_modeled = joblib.load("cancer.joblib")
load_modeled
# Out:
# model save
# (LogisticRegression(random_state=0),
#  DecisionTreeClassifier(criterion='entropy', random_state=0),
#  RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0))
